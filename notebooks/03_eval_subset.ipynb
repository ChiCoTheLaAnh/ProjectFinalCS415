# %% [markdown]
# # 03 Eval Subset
#
# Scaffold notebook for subset benchmarking after the smoke test passes.
#
# Planned usage:
#
# - prepare a dataset subset manifest under `data/processed/`
# - run `scripts/run_eval_subset.py`
# - save metrics into `results/quantitative/`
# - keep any experiment logic in repository code instead of the notebook

# %%
# Placeholder for evaluation-on-subset workflow.
