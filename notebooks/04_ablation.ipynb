# %% [markdown]
# # 04 Ablation
#
# Scaffold notebook for controlled ablation runs after the baseline is reproducible.
#
# Planned comparisons:
#
# - prompt variants
# - box and text thresholds
# - SAM2 propagation settings
# - fallback behavior diagnostics when propagation cannot initialize

# %%
# Placeholder for ablation workflow.
