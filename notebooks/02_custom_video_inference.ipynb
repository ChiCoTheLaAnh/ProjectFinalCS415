# %% [markdown]
# # 02 Custom Video Inference
#
# Scaffold notebook for running longer custom videos after the smoke test baseline is stable.
#
# Planned usage:
#
# - mount Drive
# - clone repo
# - run `bash setup_colab.sh --with-models`
# - set custom input paths and prompt
# - call `scripts/run_custom_video.py`
# - export overlays and metadata into Drive

# %%
# Placeholder for custom video inference workflow.
# Keep project logic in scripts/ and src/, not in the notebook.
